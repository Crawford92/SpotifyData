# %%
# Things to do with this project

#Probably a genre breakdown between the 3 mixes and the 6 top 100s
#[1]The weighted/unweighted top artists from top 100 lists
#[2]Add new column for what the "real" genre of a track is
#[3]Throw everything together, manually assign two classes "normie" or "weirdo" and then do like an 80/20 train/test split for an ML algo

# %% [markdown]
# [1]
# Count all the artists by frequency in the 6 top 100 playlists to create an alternate top 5 artists of the last 6 years
#
# Also create a weighted list of artists from this dataframe. So a track that was the most listened to that year counts as 1 point and the 80th most played track of that year counts as .20
#
# Worth considering that some tracks have multiple artists listed, so might require a similar strategy to [2] regarding list of lists.

# %% [markdown]
# [2]
#
# We also want to have genre breakdowns, but will need to manually correct for imaginary genres
#
# 1. In the gigaDF, there will be a column for "Genres", toList this whole column, yielding a list of lists
# 2. Iterate through the list of lists, for each inner list iterate through and append each 'genre' to a new list
# 3. implement a counter collection on that list which will yield genres and how often they appear
# 4. maybe convert that collection to dictionary if thats easier
# 5. Iterate through gigaDF, for each row, pull out every element of Genres, compare to the counter or dictionary, and assign the value of a new column "RealGenre" to whichever genre named in the "Genres" column that has the most entries
#
# Ideally, this yields a correct supergenre for each category, in practice it might not, if the "parent" genre is absent in the Genres column for an entry it could be misclassified, or if a subgenre appears with greater frequency than its parent genre it will appear as the parent. Either way test it and see how it goes.
#
# Absolute worst case scenario, manually apply RealGenre. Will have to manually apply "Normie" vs "Weirdo" anyway.

# %% [markdown]
# [3]
# Hard code by normie or weirdo, 80/20 train test, see how accurate model predicts class based on weird spotify nums (speechiness tempo valence)
#
# That way we have actually trained a ML model with sci kit

# %%
# Survivor = a track that has been present in more than one top 100 playlist

# %%
from matplotlib import pyplot
import seaborn
import pandas as pd
from collections import defaultdict
from scipy.stats import pareto, gamma
from datetime import date



megamix = 'liked_songs.csv'
mix2024 = '2024.csv'
mix2023 = '2023.csv'
mix2022 = '2022.csv'
mix2021 = '2021.csv'
mix2020 = '2020.csv'
mix2019 = '2019.csv'
mix1    = 'my_mix.csv'
mix2    = 'my_mix_part_2.csv'



# read the data
likedData = pd.read_csv(megamix)
mixOne  = pd.read_csv(mix1)
mixTwo  = pd.read_csv(mix2)
Data24  = pd.read_csv(mix2024)
Data23  = pd.read_csv(mix2023)
Data22  = pd.read_csv(mix2022)
Data21  = pd.read_csv(mix2021)
Data20  = pd.read_csv(mix2020)
Data19  = pd.read_csv(mix2019)

# %%
# print("total songs:", data.shape[0])
likedData.head(5)
# Out:
#                  Track ID          Track Name          Album Name  \
# 0  1pnDvUuAEd6z8bKEsbAjk1  We Don't Trust You  WE DON'T TRUST YOU
# 1  4I5QRJ0vpMpnzR23Lpm3k9            Whiplash            Whiplash
# 2  5ZUIPLoTLJZrPQh2kFZEUM            Addicted            Addicted
# 3  6BzU6BMqMd4qelkWTjLwKy       Only Children            Reunions
# 4  3DnsQ5O4uJw3MlYgvBJSCq           Maxed Out           Maxed Out
#
#                   Artist Name(s) Release Date  Duration (ms)  Popularity  \
# 0            Future,Metro Boomin   2024-03-22         226213          70
# 1                     Architects   2024-11-19         226166          65
# 2      Zerb,The Chainsmokers,Ink   2024-03-29         152250          81
# 3  Jason Isbell and the 400 Unit   2020-05-15         237126          46
# 4             Bayker Blankenship   2024-04-19         172607          73
#
#    Added By              Added At  \
# 0       NaN  2024-11-30T08:45:27Z
# 1       NaN  2024-11-20T05:04:38Z
# 2       NaN  2024-11-09T07:07:53Z
# 3       NaN  2024-11-06T03:00:13Z
# 4       NaN  2024-11-06T02:42:29Z
#
#                                               Genres  ... Key  Loudness  Mode  \
# 0      atl hip hop,hip hop,rap,southern hip hop,trap  ...   6    -7.169     0
# 1  mathcore,melodic metalcore,metalcore,progressi...  ...   8    -3.189     0
# 2                                      pop dance,pop  ...   5    -7.132     0
# 3  alternative country,folk,new americana,roots rock  ...   4   -10.715     0
# 4                                 modern country pop  ...   7   -10.778     0
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.2710      0.478000          0.000439    0.2430    0.346  124.091
# 1       0.1530      0.000061          0.002570    0.9000    0.423   95.041
# 2       0.0374      0.024500          0.000163    0.1110    0.190  120.064
# 3       0.0346      0.655000          0.001790    0.0858    0.236   89.499
# 4       0.0360      0.359000          0.000008    0.1060    0.364  145.915
#
#    Time Signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 23 columns]

# %%
print(likedData.columns.tolist())
# Out:
# ['Track ID', 'Track Name', 'Album Name', 'Artist Name(s)', 'Release Date', 'Duration (ms)', 'Popularity', 'Added By', 'Added At', 'Genres', 'Record Label', 'Danceability', 'Energy', 'Key', 'Loudness', 'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Time Signature']

# %%
# likedData
# Data24 
# Data23
# Data22  
# Data21 
# Data20 
# Data19
likedData[["Track Name", "Artist Name(s)"]]
# Out:
#                                             Track Name  \
# 0                                   We Don't Trust You
# 1                                             Whiplash
# 2                                             Addicted
# 3                                        Only Children
# 4                                            Maxed Out
# ..                                                 ...
# 732                                       Gotta Get It
# 733                             In the Pines (Oakland)
# 734                                             OooWee
# 735                                           Gillette
# 736  The Scotsman - Live At The Winfield National F...
#
#                            Artist Name(s)
# 0                     Future,Metro Boomin
# 1                              Architects
# 2               Zerb,The Chainsmokers,Ink
# 3           Jason Isbell and the 400 Unit
# 4                      Bayker Blankenship
# ..                                    ...
# 732  Ruin Your Day,D.I. Da Hennyman,Spiff
# 733                     Fantastic Negrito
# 734                Rapsody,Anderson .Paak
# 735                     199X,DrDisrespect
# 736                          Bryan Bowers
#
# [737 rows x 2 columns]

# %%
# Data24 
# Data23
# Data22  
# Data21 
# Data20 
# Data19

#Find songs that last through the years
#OmniTracksDF = Data24[["Track Name", "Artist Name(s)"]]
years = ["2024", "2023", "2022", "2021", "2020", "2019"]
list_of_lists = []
for i in years:
    #print(i)
    tracks = []
    artists = []
    # we dont need year as a list, just at the end, for all rows where year is NaN, set year to i
    # unless for some stupid reason python thinks a list is more efficient, for symmetry we'll do it this way for the moment
    year = []

    #This feels cartoonishly overcomplicated

    
    
    if i == "2024":
        col_one_list = Data24["Track Name"].tolist()
        col_two_list = Data24["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2024")
            list_of_lists.append(inner_list)
    if i == "2023":
        col_one_list = Data23["Track Name"].tolist()
        col_two_list = Data23["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2023")
            list_of_lists.append(inner_list)
    if i == "2022":
        col_one_list = Data22["Track Name"].tolist()
        col_two_list = Data22["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2022")
            list_of_lists.append(inner_list)
    if i == "2021":
        col_one_list = Data21["Track Name"].tolist()
        col_two_list = Data21["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2021")
            list_of_lists.append(inner_list)
    if i == "2020":
        col_one_list = Data20["Track Name"].tolist()
        col_two_list = Data20["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2020")
            list_of_lists.append(inner_list)
    if i == "2019":
        col_one_list = Data19["Track Name"].tolist()
        col_two_list = Data19["Artist Name(s)"].tolist()

        #list_of_lists = []
        rowsX = 100
        colsX = 3

        for i in range(rowsX):
            inner_list = []
            inner_list.append(col_one_list[i])
            inner_list.append(col_two_list[i])
            inner_list.append("2019")
            list_of_lists.append(inner_list)

dfX = pd.DataFrame(list_of_lists)
dfX = dfX.rename(columns={0: "Track", 1: "Artist(s)", 2: "Year"})
dfX.shape
dfX.head(5)
#dfX = pd.DataFrame()
#dfX["Track"] = Data24["Track Name"]
#dfX["Artist(s)"] = Data24["Artist Name(s)"]
#dfX.head()

#data = []
#for row in some_function_that_yields_data():
#    data.append(row)

#df = pd.DataFrame(data)
# Out:
#        Track                   Artist(s)  Year
# 0      Dante                   Northlane  2024
# 1   RATATATA  BABYMETAL,Electric Callboy  2024
# 2     labour                Paris Paloma  2024
# 3      Rucón                      Alemán  2024
# 4  Even Flow                   Pearl Jam  2024

# %%
# I think we want keep=True here because we want to include the first year that the survivor appears
dfX[dfX.duplicated('Track', keep=False) == True]
# Out:
#                                        Track                       Artist(s)  \
# 27                               Love Chains                            BOYY
# 34                               Lone Digger                  Caravan Palace
# 61                                      Down       Hemlock Ernst,Kenny Segal
# 66                           Come Check This                          FETISH
# 77                        N.Y. State of Mind                             Nas
# ..                                       ...                             ...
# 579                            Bodysnatchers           Dave Rawlings Machine
# 585                            WISH YOU WELL                        Amir Obe
# 588                           Out Of Control                      Hoobastank
# 597  Caterpillar (feat. Eminem & King Green)  Royce Da 5'9,Eminem,King Green
# 599                               Knee Socks                  Arctic Monkeys
#
#      Year
# 27   2024
# 34   2024
# 61   2024
# 66   2024
# 77   2024
# ..    ...
# 579  2019
# 585  2019
# 588  2019
# 597  2019
# 599  2019
#
# [210 rows x 3 columns]

# %%
dfX1 = dfX[dfX.duplicated('Track', keep=False) == True].copy()
dfX1["Years of Apperance"] = dfX1.groupby('Track', as_index=False)['Track'].cumcount()
#dfX1.head
dfX1 = dfX1.sort_values("Track")


#dfX1 = dfX1.sort_values("Years of Apperance")
print(dfX1.to_string())

#But since the immediate goal is to find songs that showed up the most
# Out:
#                                                                                     Track                                                                             Artist(s)  Year  Years of Apperance
# 313                                                                            60 Seconds                            Bone Thugs-N-Harmony,DJ Kay Slay,Busta Rhymes,Twista,Jaz-O  2021                   1
# 231                                                                            60 Seconds                            Bone Thugs-N-Harmony,DJ Kay Slay,Busta Rhymes,Twista,Jaz-O  2022                   0
# 445                                                                  8 Minutes 46 Seconds               Vangarde,Mr. Lif,Stu Bangas,Puma Ptah,Reef The Lost Cauze,Bluprint,Murs  2020                   1
# 363                                                                  8 Minutes 46 Seconds               Vangarde,Mr. Lif,Stu Bangas,Puma Ptah,Reef The Lost Cauze,Bluprint,Murs  2021                   0
# 407                                                                                  Bats                                                                          The Uncluded  2020                   0
# 570                                                                                  Bats                                                                          The Uncluded  2019                   1
# 360                                                                              Bilingue                                                                      Snow Tha Product  2021                   1
# 224                                                                              Bilingue                                                                      Snow Tha Product  2022                   0
# 367                                                            Bitch Better Have My Money                                                                               Rihanna  2021                   1
# 258                                                            Bitch Better Have My Money                                                                               Rihanna  2022                   0
# 579                                                                         Bodysnatchers                                                                 Dave Rawlings Machine  2019                   1
# 474                                                                         Bodysnatchers                                                                 Dave Rawlings Machine  2020                   0
# 373                                                                      Breaking Me Down                                                                                  Soil  2021                   0
# 457                                                                      Breaking Me Down                                                                                  Soil  2020                   1
# 455                                                                                Butter                                                                      Snow Tha Product  2020                   2
# 315                                                                                Butter                                                                      Snow Tha Product  2021                   1
# 298                                                                                Butter                                                                      Snow Tha Product  2022                   0
# 372                                                                   Call In the Coroner                                                                           Days N Daze  2021                   1
# 286                                                                   Call In the Coroner                                                                           Days N Daze  2022                   0
# 521                                                                   Call In the Coroner                                                                           Days N Daze  2019                   2
# 478                                          Can't Be Touched (feat. Mr. Magic & Trouble)                                                        Roy Jones Jr.,Mr Magic,Trouble  2020                   1
# 375                                          Can't Be Touched (feat. Mr. Magic & Trouble)                                                        Roy Jones Jr.,Mr Magic,Trouble  2021                   0
# 543                                          Can't Be Touched (feat. Mr. Magic & Trouble)                                                        Roy Jones Jr.,Mr Magic,Trouble  2019                   2
# 436                                               Caterpillar (feat. Eminem & King Green)                                                        Royce Da 5'9,Eminem,King Green  2020                   0
# 597                                               Caterpillar (feat. Eminem & King Green)                                                        Royce Da 5'9,Eminem,King Green  2019                   1
# 394                                                                Clouds Over California                                                                           DevilDriver  2021                   1
# 226                                                                Clouds Over California                                                                           DevilDriver  2022                   0
# 66                                                                        Come Check This                                                                                FETISH  2024                   0
# 131                                                                       Come Check This                                                                                FETISH  2023                   1
# 504                                                                              Confined                                                                        As I Lay Dying  2019                   1
# 481                                                                              Confined                                                                        As I Lay Dying  2020                   0
# 442                                                                           Cover Me Up                                                                          Jason Isbell  2020                   1
# 339                                                                           Cover Me Up                                                                          Jason Isbell  2021                   0
# 238                                                                      Curl of the Burl                                                                              Mastodon  2022                   1
# 130                                                                      Curl of the Burl                                                                              Mastodon  2023                   0
# 425                                                                              Da Joint                                                                                  EPMD  2020                   0
# 503                                                                              Da Joint                                                                                  EPMD  2019                   1
# 277                                                                   Dance with Somebody                                     Riggi & Piros,Dave Crusher,JackMar,Scarlett Quinn  2022                   1
# 192                                                                   Dance with Somebody                                     Riggi & Piros,Dave Crusher,JackMar,Scarlett Quinn  2023                   0
# 348                                                                           Danger Zone                                                                Cherlene,Kenny Loggins  2021                   1
# 276                                                                           Danger Zone                                                                Cherlene,Kenny Loggins  2022                   0
# 350                                                                   Do You Call My Name                                                                                    Ra  2021                   1
# 246                                                                   Do You Call My Name                                                                                    Ra  2022                   0
# 306                                                             Don't Rush (feat. DaBaby)                                                               Young T & Bugsey,DaBaby  2021                   1
# 234                                                             Don't Rush (feat. DaBaby)                                                               Young T & Bugsey,DaBaby  2022                   0
# 414                                                                Dove and the Waterline                                                                      Jeffrey Foucault  2020                   0
# 561                                                                Dove and the Waterline                                                                      Jeffrey Foucault  2019                   1
# 103                                                                                  Down                                                             Hemlock Ernst,Kenny Segal  2023                   1
# 256                                                                                  Down                                                             Hemlock Ernst,Kenny Segal  2022                   2
# 61                                                                                   Down                                                             Hemlock Ernst,Kenny Segal  2024                   0
# 396                                                                      Dust in a Baggie                                                                         Billy Strings  2021                   1
# 229                                                                      Dust in a Baggie                                                                         Billy Strings  2022                   0
# 412                                                                      Dust in a Baggie                                                                         Billy Strings  2020                   2
# 112                                                               Everything is Quiet Now                                                                         Knocked Loose  2023                   1
# 81                                                                Everything is Quiet Now                                                                         Knocked Loose  2024                   0
# 459                                                                  FYM (feat. Mystikal)                                                                 Joyner Lucas,Mystikal  2020                   0
# 577                                                                  FYM (feat. Mystikal)                                                                 Joyner Lucas,Mystikal  2019                   1
# 163                                                                                 Faded                                                       Besomorph,Coopex,BRAN,Nito-Onna  2023                   0
# 204                                                                                 Faded                                                       Besomorph,Coopex,BRAN,Nito-Onna  2022                   1
# 384                                                                                 Freya                                                                             The Sword  2021                   0
# 502                                                                                 Freya                                                                             The Sword  2019                   2
# 422                                                                                 Freya                                                                             The Sword  2020                   1
# 344                                                                        Fuck Everybody                                Ruin Your Day,Daylyt,Illmac,B Dot the God,Geechi Gotti  2021                   0
# 404                                                                        Fuck Everybody                                Ruin Your Day,Daylyt,Illmac,B Dot the God,Geechi Gotti  2020                   1
# 500                                                                              Gasoline                                                                          Benjamin Tod  2019                   1
# 440                                                                              Gasoline                                                                          Benjamin Tod  2020                   0
# 416                                                                                 Ghost                                                                     Au/Ra,Alan Walker  2020                   2
# 242                                                                                 Ghost                                           Au/Ra,Alan Walker,Death Stranding: Timefall  2022                   0
# 345                                                                                 Ghost                                                                     Au/Ra,Alan Walker  2021                   1
# 408                                                                                 Guilt                                                                                  NERO  2020                   1
# 338                                                                                 Guilt                                                                                  NERO  2021                   0
# 562                                                                                 Guilt                                                                                  NERO  2019                   2
# 111                                                                HUMANS - Far Out Remix                                                                     GEN.KLOUD,Far Out  2023                   0
# 208                                                                HUMANS - Far Out Remix                                                                     GEN.KLOUD,Far Out  2022                   1
# 96                                                                              Headstone                                                                      Flatbush Zombies  2024                   0
# 491                                                                             Headstone                                                                      Flatbush Zombies  2020                   1
# 260                                                               I Knew You Were Trouble                                                                     We Came As Romans  2022                   0
# 323                                                               I Knew You Were Trouble                                                                     We Came As Romans  2021                   1
# 343                                                                   If We Were Vampires                                                         Jason Isbell and the 400 Unit  2021                   0
# 456                                                                   If We Were Vampires                                                         Jason Isbell and the 400 Unit  2020                   1
# 349                                                      Immigrants (We Get The Job Done)                                           K'NAAN,Snow Tha Product,Riz Ahmed,Residente  2021                   0
# 482                                                      Immigrants (We Get The Job Done)                                           K'NAAN,Snow Tha Product,Riz Ahmed,Residente  2020                   1
# 332                                                                              Informer                                                                                  Snow  2021                   1
# 271                                                                              Informer                                                                                  Snow  2022                   0
# 539  It Ain't Easy, It Ain't Easy (feat. Nyck Caution, Kirk Knight, CJ Fly & AKTHESAVIOR)  Beast Coast,Joey Bada$$,Flatbush Zombies,Nyck Caution,Kirk Knight,CJ Fly,AKTHESAVIOR  2019                   2
# 438  It Ain't Easy, It Ain't Easy (feat. Nyck Caution, Kirk Knight, CJ Fly & AKTHESAVIOR)  Beast Coast,Joey Bada$$,Flatbush Zombies,Nyck Caution,Kirk Knight,CJ Fly,AKTHESAVIOR  2020                   1
# 358  It Ain't Easy, It Ain't Easy (feat. Nyck Caution, Kirk Knight, CJ Fly & AKTHESAVIOR)  Beast Coast,Joey Bada$$,Flatbush Zombies,Nyck Caution,Kirk Knight,CJ Fly,AKTHESAVIOR  2021                   0
# 209                                          It Takes a Seven Nation Army to Hold Us Back                                                                   Apathy,Emilio Lopez  2022                   0
# 304                                          It Takes a Seven Nation Army to Hold Us Back                                                                   Apathy,Emilio Lopez  2021                   1
# 261                                                                         Kate McCannon                                                                           Colter Wall  2022                   0
# 335                                                                         Kate McCannon                                                                           Colter Wall  2021                   1
# 410                                                                         Kate McCannon                                                                           Colter Wall  2020                   2
# 381                                                                             Kill Bill                                                                      Brown Eyed Girls  2021                   0
# 496                                                                             Kill Bill                                                                      Brown Eyed Girls  2020                   1
# 599                                                                            Knee Socks                                                                        Arctic Monkeys  2019                   2
# 484                                                                            Knee Socks                                                                        Arctic Monkeys  2020                   1
# 383                                                                            Knee Socks                                                                        Arctic Monkeys  2021                   0
# 443                                                                        Little Monster                                                                           Royal Blood  2020                   0
# 571                                                                        Little Monster                                                                           Royal Blood  2019                   1
# 514                                                                           Lone Digger                                                                        Caravan Palace  2019                   1
# 34                                                                            Lone Digger                                                                        Caravan Palace  2024                   0
# 411                                                                        Lone Pine Hill                                                                   Justin Townes Earle  2020                   1
# 240                                                                        Lone Pine Hill                                                                   Justin Townes Earle  2022                   0
# 525                                                                        Lone Pine Hill                                                                   Justin Townes Earle  2019                   2
# 391                                                                   Long Live the Chief                                                                               Jidenna  2021                   0
# 454                                                                   Long Live the Chief                                                                               Jidenna  2020                   1
# 574                                                                   Long Live the Chief                                                                               Jidenna  2019                   2
# 27                                                                            Love Chains                                                                                  BOYY  2024                   0
# 203                                                                           Love Chains                                                                                  BOYY  2022                   1
# 266                                                                          Me Recuerdas                                                                            Yoss Bones  2022                   0
# 355                                                                          Me Recuerdas                                                                            Yoss Bones  2021                   1
# 428                                                    My Name (feat. Eminem & Nate Dogg)                                                               Xzibit,Eminem,Nate Dogg  2020                   0
# 555                                                    My Name (feat. Eminem & Nate Dogg)                                                               Xzibit,Eminem,Nate Dogg  2019                   1
# 77                                                                     N.Y. State of Mind                                                                                   Nas  2024                   0
# 461                                                                    N.Y. State of Mind                                                                                   Nas  2020                   1
# 557                                                                                 NEVER                                                                                   JID  2019                   1
# 462                                                                                 NEVER                                                                                   JID  2020                   0
# 464                                                                       None Shall Pass                                                                            Aesop Rock  2020                   1
# 296                                                                       None Shall Pass                                                                            Aesop Rock  2022                   0
# 376                                            Nose on the Grindstone (OurVinyl Sessions)                                                               Tyler Childers,OurVinyl  2021                   0
# 406                                            Nose on the Grindstone (OurVinyl Sessions)                                                               Tyler Childers,OurVinyl  2020                   1
# 392                                                                   Nothing For Me Here                                                                                  Dope  2021                   1
# 241                                                                   Nothing For Me Here                                                                                  Dope  2022                   0
# 488                                                                                 Oh No                                                      Mos Def,Pharoahe Monch,Nate Dogg  2020                   0
# 519                                                                                 Oh No                                                      Mos Def,Pharoahe Monch,Nate Dogg  2019                   1
# 225                                                                                OooWee                                                                Rapsody,Anderson .Paak  2022                   0
# 401                                                                                OooWee                                                                Rapsody,Anderson .Paak  2020                   2
# 325                                                                                OooWee                                                                Rapsody,Anderson .Paak  2021                   1
# 268                                                                        Out Of Control                                                                            Hoobastank  2022                   0
# 432                                                                        Out Of Control                                                                            Hoobastank  2020                   2
# 319                                                                        Out Of Control                                                                            Hoobastank  2021                   1
# 588                                                                        Out Of Control                                                                            Hoobastank  2019                   3
# 322                                                       P-Funk (Wants To Get Funked Up)                                                                            Parliament  2021                   1
# 297                                                       P-Funk (Wants To Get Funked Up)                                                                            Parliament  2022                   0
# 518                                                                           Psychoville                                                                      Dabbla,Graziella  2019                   2
# 395                                                                           Psychoville                                                                      Dabbla,Graziella  2021                   1
# 294                                                                           Psychoville                                                                      Dabbla,Graziella  2022                   0
# 279                                                                              Renegade                                                                                  Styx  2022                   0
# 333                                                                              Renegade                                                                                  Styx  2021                   1
# 311                                                                 Roses - Imanbek Remix                                                                     SAINt JHN,Imanbek  2021                   1
# 426                                                                 Roses - Imanbek Remix                                                                     SAINt JHN,Imanbek  2020                   2
# 206                                                                 Roses - Imanbek Remix                                                                     SAINt JHN,Imanbek  2022                   0
# 510                                                        Salió El Sol - Remastered 2016                                                                              Don Omar  2019                   1
# 489                                                        Salió El Sol - Remastered 2016                                                                              Don Omar  2020                   0
# 575                                                                    Shook Ones, Pt. II                                                                             Mobb Deep  2019                   2
# 188                                                                    Shook Ones, Pt. II                                                                             Mobb Deep  2023                   0
# 448                                                                    Shook Ones, Pt. II                                                                             Mobb Deep  2020                   1
# 468                                                                                Shrunk                                                                            Aesop Rock  2020                   1
# 267                                                                                Shrunk                                                                            Aesop Rock  2022                   0
# 400                                                              Sleeping on the Blacktop                                                                           Colter Wall  2020                   2
# 314                                                              Sleeping on the Blacktop                                                                           Colter Wall  2021                   1
# 215                                                              Sleeping on the Blacktop                                                                           Colter Wall  2022                   0
# 305                                        Snow Tha Product: Bzrp Music Sessions, Vol. 39                                                             Bizarrap,Snow Tha Product  2021                   1
# 236                                        Snow Tha Product: Bzrp Music Sessions, Vol. 39                                                             Bizarrap,Snow Tha Product  2022                   0
# 244                                                                              Stigmata                                                                              grandson  2022                   0
# 493                                                                              Stigmata                                                                              grandson  2020                   2
# 378                                                                              Stigmata                                                                              grandson  2021                   1
# 308                                                                         Straight Line                                                                         Pete Bernhard  2021                   1
# 220                                                                         Straight Line                                                                         Pete Bernhard  2022                   0
# 302                                                                               Streets                                                                              Doja Cat  2021                   1
# 217                                                                               Streets                                                                              Doja Cat  2022                   0
# 362                                                                                Studio                                                        ScHoolboy Q,BJ The Chicago Kid  2021                   0
# 405                                                                                Studio                                                        ScHoolboy Q,BJ The Chicago Kid  2020                   1
# 144                                                                Thank You [Not So Bad]                                                                      VIZE,Felix Jaehn  2023                   0
# 202                                                                Thank You [Not So Bad]                                                                      VIZE,Felix Jaehn  2022                   1
# 385                            The Chain - From the Motion Picture Soundtrack The Kitchen                 The Highwomen,Brandi Carlile,Natalie Hemby,Maren Morris,Amanda Shires  2021                   1
# 295                            The Chain - From the Motion Picture Soundtrack The Kitchen                 The Highwomen,Brandi Carlile,Natalie Hemby,Maren Morris,Amanda Shires  2022                   0
# 265                                                        The Devil Wears a Suit and Tie                                                                           Colter Wall  2022                   0
# 309                                                        The Devil Wears a Suit and Tie                                                                           Colter Wall  2021                   1
# 446                                                        The Devil Wears a Suit and Tie                                                                           Colter Wall  2020                   2
# 299                                           The Formula (feat. Tech N9ne, Krizz Kaliko)                                                          Rittz,Tech N9ne,Krizz Kaliko  2022                   0
# 576                                           The Formula (feat. Tech N9ne, Krizz Kaliko)                                                          Rittz,Tech N9ne,Krizz Kaliko  2019                   1
# 248                                                         The Night (OurVinyl Sessions)                                                                  Morgan Wade,OurVinyl  2022                   0
# 300                                                         The Night (OurVinyl Sessions)                                                                  Morgan Wade,OurVinyl  2021                   1
# 566                                                                   The Real Slim Shady                                                                                Eminem  2019                   1
# 450                                                                   The Real Slim Shady                                                                                Eminem  2020                   0
# 190                                                                            The Sinner                                                                      Memphis May Fire  2023                   0
# 351                                                                            The Sinner                                                                      Memphis May Fire  2021                   1
# 444                                                                          Them Changes                                                                            Thundercat  2020                   0
# 565                                                                          Them Changes                                                                            Thundercat  2019                   1
# 393                                                                  These Men Are Wolves                                                                        The Heavy Eyes  2021                   1
# 235                                                                  These Men Are Wolves                                                                        The Heavy Eyes  2022                   0
# 516                                                                           Thunderhead                                                                       The Native Howl  2019                   1
# 475                                                                           Thunderhead                                                                       The Native Howl  2020                   0
# 449                                                              Time > Breathe Reprise >                                                                    Greensky Bluegrass  2020                   1
# 379                                                              Time > Breathe Reprise >                                                                    Greensky Bluegrass  2021                   0
# 585                                                                         WISH YOU WELL                                                                              Amir Obe  2019                   1
# 498                                                                         WISH YOU WELL                                                                              Amir Obe  2020                   0
# 465                                                                          Wait so Long                                                                   Trampled by Turtles  2020                   1
# 515                                                                          Wait so Long                                                                   Trampled by Turtles  2019                   2
# 334                                                                          Wait so Long                                                                   Trampled by Turtles  2021                   0
# 210                                                                            Wake Me Up                                                                                Avicii  2022                   1
# 143                                                                            Wake Me Up                                                                                 Foals  2023                   0
# 312                                                                            Wake Me Up                                                                                Avicii  2021                   2
# 492                                                              Way Farer (2017 Version)                                                                                  Sung  2020                   1
# 263                                                              Way Farer (2017 Version)                                                                                  Sung  2022                   0
# 195                                                         Weekend (feat. Emelie Cyréus)                                                                   LIZOT,Emelie Cyréus  2023                   0
# 284                                                         Weekend (feat. Emelie Cyréus)                                                                   LIZOT,Emelie Cyréus  2022                   1
# 243                                                                   When God Comes Back                                                                      All Them Witches  2022                   0
# 336                                                                   When God Comes Back                                                                      All Them Witches  2021                   1
# 409                                                                   When God Comes Back                                                                      All Them Witches  2020                   2
# 100                                                                       Where Do We Go?                                                                    WEISS,Harry Romero  2023                   1
# 87                                                                        Where Do We Go?                                                                    WEISS,Harry Romero  2024                   0
# 415                                                                 Will You Remember Me?                                                                     The Pine Box Boys  2020                   0
# 563                                                                 Will You Remember Me?                                                                     The Pine Box Boys  2019                   1
# 501                                                   You Don't Care for Me Enough to Cry                                                                         John Moreland  2019                   2
# 424                                                   You Don't Care for Me Enough to Cry                                                                         John Moreland  2020                   1
# 179                                                   You Don't Care for Me Enough to Cry                                                                         John Moreland  2023                   0
# 230                                                                                   Шум                                                                                  Go_A  2022                   0
# 301                                                                                   Шум                                                                                  Go_A  2021                   1

# %%
#So 25 songs have appeared in 3 years, 1 appeared in 4 years, and sadly none have run the table

# %%
#Okay so this isn't actually that cool because the split is like, 3 is the most for billy joel (2024), so we should look at all top 100s for this

# count songs per artist
artists = defaultdict(int)
for i,song in Data24.iterrows():
    if isinstance(song['Artist Name(s)'], str):
    	for musician in song['Artist Name(s)'].split(','):
    		artists[musician] += 1

# sort for chart
artists = pd.DataFrame(artists.items(), columns=['Artist', 'Num Songs']
                          ).sort_values('Num Songs', ascending=False).reset_index(drop=True)
print("number of unique artists:", artists.shape[0])

pyplot.figure(figsize=(18, 6))
pyplot.bar(artists['Artist'], artists['Num Songs'])
pyplot.xticks(visible=False)
pyplot.xlabel(artists.columns[0])
pyplot.ylabel(artists.columns[1])
pyplot.title('everybody')
pyplot.show()
# Out:
# number of unique artists: 117

# %%
pyplot.figure(figsize=(18, 10))
pyplot.bar(artists['Artist'][:50], artists['Num Songs'][:50])
pyplot.xticks(rotation=80)
pyplot.xlabel(artists.columns[0])
pyplot.ylabel(artists.columns[1])
pyplot.title('top 50');

# %%
tempGigaDF1 = pd.concat([Data24, Data23], ignore_index=True)
tempGigaDF2 = pd.concat([Data22, Data21], ignore_index=True)
tempGigaDF3 = pd.concat([Data20, Data19], ignore_index=True)

tempGigaDF = pd.concat([tempGigaDF1, tempGigaDF2], ignore_index=True)
tempGigaDF = pd.concat([tempGigaDF, tempGigaDF3], ignore_index=True)

# count songs per genre


genres = defaultdict(int)
for i,song in tempGigaDF.iterrows():
    if type(song['Genres']) is str: # some times there aren't any, and this is NaN
        for genre in song['Genres'].split(','):
            if len(genre) > 0: # empty string seems to be a legit genre
                genres[genre] += 1

# sort for chart
genres = pd.DataFrame(genres.items(), columns=['Genre', 'Num Songs']
                          ).sort_values('Num Songs', ascending=False).reset_index(drop=True)
print("number of unique genres:", genres.shape[0])

pyplot.figure(figsize=(18, 6))
pyplot.bar(genres['Genre'], genres['Num Songs'])
pyplot.xticks(visible=False)
pyplot.xlabel(genres.columns[0])
pyplot.ylabel(genres.columns[1])
pyplot.title('All the genera');
# Out:
# number of unique genres: 563

# %%
pyplot.figure(figsize=(18, 10))
pyplot.bar(genres['Genre'][:50], genres['Num Songs'][:50])
pyplot.xticks(rotation=80)
pyplot.xlabel(genres.columns[0])
pyplot.ylabel(genres.columns[1])
pyplot.title('top 50');

pyplot.savefig("top 50.png", bbox_inches="tight")

# %%
pyplot.figure(figsize=(18, 1))
pyplot.bar(genres['Genre'][-50:], genres['Num Songs'][-50:])
pyplot.xticks(rotation=80)
pyplot.xlabel(genres.columns[0])
pyplot.ylabel(genres.columns[1])
pyplot.title('bottom 50');

# %%
genres.head
# Out:
# <bound method NDFrame.head of                      Genre  Num Songs
# 0                  hip hop         58
# 1        alternative metal         43
# 2                      rap         39
# 3            new americana         30
# 4             gangster rap         30
# ..                     ...        ...
# 558        indie poptimism          1
# 559          bronx hip hop          1
# 560                bagpipe          1
# 561  bagpipe marching band          1
# 562               etherpop          1
#
# [563 rows x 2 columns]>

# %%
genres.loc[genres['Num Songs'] == 1]
# Out:
#                      Genre  Num Songs
# 333      garage punk blues          1
# 334        one-person band          1
# 335          halifax indie          1
# 336              dark folk          1
# 337              dark trap          1
# ..                     ...        ...
# 558        indie poptimism          1
# 559          bronx hip hop          1
# 560                bagpipe          1
# 561  bagpipe marching band          1
# 562               etherpop          1
#
# [230 rows x 2 columns]

# %%
#Okay so, 563 genres in the top 600.....which looks weird to me, maybe check that
#230 genres are singles
#so 333 genres are at least 2, which....OH you know what I bet this is because a track can have many genres
#Yeah okay it definitely is
